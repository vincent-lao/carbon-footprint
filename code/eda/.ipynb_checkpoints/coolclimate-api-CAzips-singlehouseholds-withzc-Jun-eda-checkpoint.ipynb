# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## Input Data Description and Data Acquisition
# 1. The origins of your data. Where did you get the data? How were the data collected from the original sources?
# 2. The structure, granularity, scope, temporality and faithfulness (SGSTF) of your data. To discuss these attributes you should load the data into one or more data frames (so you'll start building code cells for the first time). At a minimum, use some basic methods (.head, .loc, and so on) to provide support for the descriptions you provide for SGSTF.
#
# This dataset was obtained from the CoolClimate API. The carbon footprint calculator is a tool created by the CoolClimate Network. This calculator allows households to calculate their total carbon footprints by inputting certain values into the calculator. Some of these group of inputs include:
# - number of adults/children in household
# - transportation
# - housing
# - shopping foods and goods
#
# We are trying to replicate this carbon footprint calculator for our final project. However, we plan on using less features. The "input_footprint" variables are the features the user inputs their values. Since we are also creating a calculator, we will be mostly focusing on the "input_footprint" variables as our features.
#
#
# Credentials were needed in order to access the api. We using the `requests` library and the app id and key given to us to extract the data from the API. This step was very slow and tedious, as we had a limitation of 10 requests per minute, where each request only gave us 1 row of data. Iterating over several parameters and thousands of zip codes, we eventually got data from all California and Texas zip codes. The data acquisition work is in [this notebook](cool-climate-api-data-acquisition-vl.ipynb).
#
# Below is one of the .csv files we created from the API.

# %% [markdown]
# ### EDA:Structure
#
# After extracting the data from the API, we turned the dataset into a csv file. Each entry is a household and its total carbon footprint value. We convert this csv file into a pandas dataframe by doing pd.read_csv.
#
# Overall, we see there are 1290 rows and 337 column to explore.

# %%
coolClimate = pd.read_csv('../../data/coolclimate-api-CAzips-singlehouseholds-withzc.csv')
coolClimate.head()
# Out:
#    Unnamed: 0  failed  error_code  input_location_mode  input_size  \
# 0           0     NaN         NaN                  1.0         1.0
# 1           0     NaN         NaN                  1.0         1.0
# 2           0     NaN         NaN                  1.0         1.0
# 3           0     NaN         NaN                  1.0         1.0
# 4           0     NaN         NaN                  1.0         1.0
#
#    input_income  input_population  input_changed  \
# 0           1.0           54587.0            0.0
# 1           1.0           44342.0            0.0
# 2           1.0           59003.0            0.0
# 3           1.0           67859.0            0.0
# 4           1.0           43032.0            0.0
#
#    input_footprint_household_adults  input_footprint_household_children  ...  \
# 0                               1.0                                 0.0  ...
# 1                               1.0                                 0.0  ...
# ...

# %% [markdown]
# ### EDA:Granularity
#
# In terms of the granularity, each row of data represents a household's **estimated** carbon emissions. There are a total of 1290 rows in this dataset and 337 columns. This means there were 1290 households that inputted data. Given that there is nothing that contains a summary row, we believe that all the records capture granularity at the same level.

# %%
coolClimate.shape
# Out:
# (1290, 337)

# %% [markdown]
# ### EDA:Scope
#
# The scope of this dataset is all the Zip Codes in California. We extracted only the households in CA. Below is the list of all the Zip Codes. Out of the 1290 rows, 1018 of them are unique zip codes. This means there were households in this dataset living in the same area.

# %%
coolClimate['Zip Code']
# Out:
# 0       90001.0
# 1       90002.0
# 2       90003.0
# 3       90004.0
# 4       90005.0
#          ...
# 1285    96052.0
# 1286    96054.0
# 1287    96055.0
# 1288    96056.0
# 1289    96057.0
# Name: Zip Code, Length: 1290, dtype: float64

# %%
len(coolClimate['Zip Code'].unique())
# Out:
# 1018

# %% [markdown]
# ### EDA:Temporality
# There are no date and time fields in this dataset. There also doesn't seem to have any timestamps of some sort

# %% [markdown]
# ### EDA:Faithfulness
#
# There does not seem to be a lot of unrealistic or incorrect values in the data, but we noticed that some columns had the same value for all the rows. The column 'result_takeaction_low_carbon_diet_meatcal', for example, had a unique value of 244.35. There are several columns like this that have the same value in all rows. We assumed that these might be default values or something like that, but it was not stated in the data dictionary.

# %%
coolClimate['result_takeaction_low_carbon_diet_meatcal'].unique()
# Out:
# array([244.35])

# %% [markdown]
# ---
#
# ## Data Cleaning
#
# First, I dropped the columns: "Unnamed: 0", "failed", and "error_code". Those columns had a buch of NaN and 0 values and were not useful overall for modelling. We also noticed that the features that had "input_footprint" were the inputs to the calculator. We were not quite sure what the "input takeaction" variables were, and we did not see those variable inputs in the CoolClimate Calculator, so we decided to drop all the variables that had "input takeaction" in it.
#
# We then discussed which of the "input footprint" variables would be easy to input for a regular user. We narrowed down our choices to the following features below. We believe these features are easiest to input. We also decided to get rid of rows that contained NaN values.

# %%
X = coolClimate[['input_income', 'input_footprint_transportation_num_vehicles', 
                 'input_footprint_transportation_mpg1', 
                 'input_footprint_transportation_miles1', 
                 'input_footprint_transportation_fuel1', 
                 'input_footprint_transportation_airshort', 
                 'input_footprint_transportation_airmedium',
                 'input_footprint_transportation_airlong', 
                 'input_footprint_housing_cdd', 'input_footprint_housing_hdd', 
                 'input_footprint_housing_electricity_dollars', 
                 'input_footprint_housing_squarefeet', 'input_footprint_housing_watersewage', 
                 'input_footprint_shopping_food_meatfisheggs_default', 
                 'input_footprint_shopping_goods_clothing', 
                 'input_footprint_shopping_goods_other_personalcare', 'input_footprint_shopping_services_education', 
                 'input_footprint_shopping_services_total']]

y = coolClimate['result_grand_total']
labels = X[X.isna().any(axis=1)].index.values
newX = X.dropna(axis = 0, how = 'any')
newy = y.drop(labels, axis = 0)

data = newX
data['result_grand_total'] = newy
data
# Out:
# /Users/junkang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       input_income  input_footprint_transportation_num_vehicles  \
# 0              1.0                                          1.0
# 1              1.0                                          1.0
# 2              1.0                                          1.0
# 3              1.0                                          1.0
# 4              1.0                                          1.0
# ...            ...                                          ...
# 1285          11.0                                          2.0
# 1286          11.0                                          2.0
# ...

# %% [markdown]
# <h1> Visualizations </h1>

# %% [markdown]
# Below are some interesting visualizations we created that show immediate relationships in the data. Below we have plotted:
# - The relationship between input_footprint_shopping_services_household and the result_grand_total
# - The relationship between input_footprint_transportation_miles1 and the result_grand_total
# - The relationship between input_footprint_housing_electricity_dollars and the result_grand_total

# %%
data.columns
# Out:
# Index(['input_income', 'input_footprint_transportation_num_vehicles',
#        'input_footprint_transportation_mpg1',
#        'input_footprint_transportation_miles1',
#        'input_footprint_transportation_fuel1',
#        'input_footprint_transportation_airshort',
#        'input_footprint_transportation_airmedium',
#        'input_footprint_transportation_airlong', 'input_footprint_housing_cdd',
#        'input_footprint_housing_hdd',
#        'input_footprint_housing_electricity_dollars',
#        'input_footprint_housing_squarefeet',
#        'input_footprint_housing_watersewage',
#        'input_footprint_shopping_food_meatfisheggs_default',
#        'input_footprint_shopping_goods_clothing',
#        'input_footprint_shopping_goods_other_personalcare',
#        'input_footprint_shopping_services_education',
#        'input_footprint_shopping_services_total', 'result_grand_total'],
#       dtype='object')

# %%
X = data['input_footprint_shopping_services_total']
y = data['result_grand_total']
plt.scatter(X,y)
plt.xlabel("Shopping Services Total")
plt.ylabel("Total Carbon Footprint Value")
plt.title('Shopping Services Total with Total Carbon Footprint Value')
plt.show()

# %%
X = data['input_footprint_transportation_miles1']
y = data['result_grand_total']
plt.scatter(X,y)
plt.xlabel("transportation miles1")
plt.ylabel("Total Carbon Footprint Value")
plt.title('transportation miles1 with Total Carbon Footprint Value')
plt.show()

# %%
X = data['input_footprint_housing_electricity_dollars']
y = data['result_grand_total']
plt.scatter(X,y)
plt.xlabel("Shopping Services Household")
plt.ylabel("The total  ")
plt.title('')
plt.show()
