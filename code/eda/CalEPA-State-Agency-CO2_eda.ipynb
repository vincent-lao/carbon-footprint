# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h1> Input Data Description, Data Cleaning, Data Summary & EDA: California EPA State Agency CO2 </h1>

# %% [markdown]
# <h1> Input Data Description </h1>
#
# This data originates from the California EPA. In this dataset, CO2 emissions are recorded from various government sources. This data is manually inputted by state agency reporters into their web-based Climate Registry Information System (CRIS) tool.
#
# The data along with the data dictionary can be downloaded at the link [here](https://data.ca.gov/dataset/calepa-state-agency-co2).
#
#
# 2. The structure, granularity, scope, temporality and faithfulness (SGSTF) of your data. To discuss these attributes you should load the data into one or more data frames (so you'll start building code cells for the first time). At a minimum, use some basic methods (.head, .loc, and so on) to provide support for the descriptions you provide for SGSTF.

# %%
epa_data = pd.read_csv('../../data/state-agency-co2e-data-2010-2014.csv')
epa_data.head()
# Out:
#                            Organization Name  Emission Year  \
# 0  California Department of General Services           2013
# 1  California Department of General Services           2010
# 2  California Department of General Services           2010
# 3  California Department of General Services           2010
# 4  California Department of General Services           2010
#
#         Facility Name Source Name                         Activity Type  \
# 0  000 Fleet Vehicles         NaN      SEM: Mobile Combustion - Scope 1
# 1       Lease#2243001         NaN  SEM: Purchased Electricity - Scope 2
# 2       Lease#5098002         NaN  SEM: Purchased Electricity - Scope 2
# 3       Lease#5107001         NaN  SEM: Purchased Electricity - Scope 2
# 4       Lease#5368001         NaN  SEM: Purchased Electricity - Scope 2
#
#   Fuel Type Fuel End Use Sector Technology        CO2e
# 0       N\A  N\A            N\A        N\A  563.025594
# 1       N\A  N\A            N\A        N\A  848.793031
# 2       N\A  N\A            N\A        N\A   12.768303
# 3       N\A  N\A            N\A        N\A    4.683929
# 4       N\A  N\A            N\A        N\A    0.265898

# %% [markdown]
# <h1> EDA: Structure, Granularity, Scope, Temporality and Faithfulness </h1>

# %% [markdown]
# # Structure
#
# The data was uploaded onto the California EPA official government website, and it was hosted in a csv file format which made it easy to convert to a Dataframe.
#
# # Granularity
#
# In looking at the granularity of the data, each record in the Dataframe represents the carbon emissions for the different government agencies. We see that data includes, for example, carbon emissions of a government building, government-owned vehicle, and even an entire fleet of government-owned vehicles. Given that there is nothing that contains a summary row, we believe that all the records capture granularity at the same level. Because the government agencies have the option to input their individual facilities, they are able to aggregate the sources at the agency level.
#
# # Scope
#
# The scope of the data covers the equivalent carbon emissions from various  Government Agencies in California sourced from California EPA.
#
# # Temporality
#
# The data is collected over a period of 4 years. More specifically, the data ranges from:
#
# 2010-01-01T05:00:00+00:00 THROUGH 2014-12-31T05:00:00+00:00
#
# # Faithfulness
#
# The data originates from the California Environmental Protection Agency which is a reliable source. However, there are a good amount of NaN values. In addition, because they are manually inputted, it would be a great idea to look at any input errors.

# %% [markdown]
# # Data Cleaning and Visualizations
#
# We see that some of the inputs in 'Source Name' -- particularly with the word 'Electricity' -- were inputted differently, so we look to correct this.

# %%
epa_data['Source Name'].unique()#value_counts()
# Out:
# array([nan, 'Electricity', 'Natural Gas', 'Van', 'Honda', 'Gasoline',
#        'Propane Gas', 'E-85', 'CNG', 'Unleaded Gas', 'Diesel', 'Gas',
#        'Purchased Electricty', 'Purchased Electricity',
#        'Gas purchase Therms', 'Alternate Fuel Vehicles',
#        'Diesel Fuel Vehicles', 'Passenger vehicles and trucks',
#        'Puchased Electricity',
#        'E-85 biogenic emissions (Light Duty Vehicles PC & Van)',
#        'CNG (Medium and Heavy Duty Vehicles)',
#        'E-85 anthropogenic emissions (Gasoline Light Trucks, Vans, Pickup Trucks, SUVs)',
#        'Dual Propane/Unleaded (Forklifts)',
#        'Gasoline (Medium and Heavy Duty Trucks)',
#        'Gasoline (Passenger Cars)',
#        'Diesel Vehicles (Medium and Heavy Duty Vans, Pickup Trucks, Trucks)',
#        'Methanol Passenger Cars', 'Diesel Vehicles (Tractors)',
#        'Gasoline Light Trucks (Vans, Pickup Trucks, SUVs)',
#        'Purchased electricity (owned and leased)',
#        'Purchased natural gas (leased)', 'Purchased natural gas (owned)',
#        'E-85 biogenic emissions (Medium and Heavy Duty Vehicles)',
#        'E-85 anthropogenic emissions (Gasoline Medium and Heavy-Duty Trucks)',
#        'E-85 anthropogenic emissions (Gasoline Passenger Cars)',
#        'E-85 biogenic emissions (Light Duty Vehicles PC,Pick-up & Van)',
#        'Motor Gasoline', 'LPG', 'Diesel Red Dye', 'Motor Fuel',
#        'Propane - Forklifts', 'Fuel CNG', 'Regular Fuel', 'NATURAL GAS',
#        'Propane', 'Diesel ', 'Alternative Fuel - Biogenic',
#        'Standard  Gasoline - Heavy Duty Vehicles',
#        'Standard Fuel - Light Trucks', 'Standard Gasoline- Cars',
#        'Alternative Fuel - Anthropogenic', 'propane', 'GASOLINE',
#        'DIESEL', 'ELECTRICITY', 'LIQUIFIED PETROLEUM GAS',
#        'COMPRESSED NATURAL GAS', 'PROPANE', 'AVIATION FUEL',
#        'Aviation Fuel', 'ELECTRCITIY', 'Compressed Natural Gas',
#        'Kerosene', 'E85', 'ELECTRIC', 'Chilled Water', 'KEROSENE',
#        'Purchased Gasoline', 'Gaoline', 'Purchased Diesel', 'Propone',
#        'Natural gas', 'Purchased gasoline', 'Purchased diesel',
#        'Purchased electricity', 'Purchased propane', 'Purchased CNG',
#        'Purchased LPG', 'Purchased natural gas', 'Purchased E85',
#        'Purchased electriity', 'purchased diesel', 'Purchased gas',
#        'Purchased marine fuel', 'Purchased propaqne',
#        'Purchased kerosene', 'Purchased Natural Gas', 'Diesel fuel',
#        'Motor gasoline', 'Aviation Gas', 'Jet Fuel',
#        'OFAM Fuel Force E-85', 'Voyager Fuel E-85', 'OFAM Fuel Force CNG',
#        'Travel Expense Claims State Garage',
#        'Voyager Fuel Card DGS Accounts', 'City of Redlands CNG',
#        'Clean Energy Fuel Card CNG', 'PG&E Fuel Card',
#        'Voyager Fuel Card Diesel', 'FLEET Star Fuel Card CNG',
#        'Pinnacle Fuel Card', 'Voyager Fuel Card CNG',
#        'OFAM Fuel Force Data', 'Trillium Fuel Card',
#        'Gasoline Grounds Equipment', 'Grounds Vehicles Diesel',
#        'Grounds Vehicles Gasoline', 'Stationary Combustion', 'Steam',
#        'So-Cal-Gas CNG', 'Emergency Generator',
#        'OFAM Fuel Force Data E-85', 'Voyager Fuel Card Report',
#        'Voyager Fuel Card Report  All DGS Accounts',
#        'Diesel Fuel Grounds Vehicles', 'Electricty',
#        'Stationary Combustion NG', 'Stationary Combustion Diesel',
#        'Mail Operation Center Van', 'ADP (1700 K St.)',
#        'DHCS Swing Space (1000 G Street)',
#        'DHCS Swing Space (300 Capitol Mall)',
#        'Fresno Field Office (North Fresno St.)',
#        'LA Legal Field Office (So. Figueroa St.)',
#        'Orange A&I Field Office (The City Dr.)', 'Total Electricity',
#        'Total Natural Gas', 'Purchase Electricity', 'Auto Fuel (Gas)',
#        'Compressed Natural Gas CNG', 'Diesel Fuel', 'Unleaded Fuel',
#        'PG&E Purchased Electricity',
#        'Marin Clean Energy Purchased Electricity', 'Electric', '1020661',
#        '1020668', 'E905951', 'E995795', '1024699', '1086126', '1228871',
#        'E884244', '1166964', 'E427387', '1090726', 'E423714', 'E959902',
#        'E962868', '1286758', '1286760', '200 E. Santa Clara Street',
#        '2000 E. Forth Street', '21731 Ventura Blvd',
#        '2529 West March Lane', '3435 Wilshire Blvd',
#        '411 N. Central Avenue', '6167 Bristol Parkway',
#        '811 Wilshire Blvd', '8880 Rio San Diego',
#        '650 E. Hospitality Lane', '101 North Brand Blvd',
#        '15333 Ave. of Science', '377 West Spruce Avenue',
#        '400 Continental Blvd', 'Vehicles-Gasoline-ASH',
#        'Vehicles - Diesel - ASH', 'Purchased Electricity-ASH',
#        'Natural Gas-ASH', 'Vehicles - Diesel - CSH',
#        'Vehicles - Gas - CSH', 'Purchased Electricity - CSH',
#        'Natural Gas - CSH', 'Purchased Electricity - MSH',
#        'Vehicles - Gas - MSH', 'Vehicles - Diesel - MSH',
#        'Natural Gas - MSH', 'Vehicles - Diesel - NSH',
#        'Vehicles - Gas - NSH', 'Purchased Electricity - NSH',
#        'Natural Gas - NSH', 'Vehicles - Diesel - PSH',
#        'Vehicles - Gas - PSH', 'Purchased Electricity - PSH',
#        'Natural Gas - PSH', 'Vehicles - Gas - SVSH',
#        'Vehicles - Gas - VSH', 'Vehicle - Fuel E85',
#        'Vehicle Fuel - Buses - CNG',
#        'Mobile Equipment -  Non-highway - Propane',
#        'Vehicle Fuel - Light Duty -Gasoline - Stockton',
#        'Vehicle Fuel - Heavy Duty - Gasoline- Stockton',
#        'Mobile Equipment-Non-Highway-Forklifts -LPG/Propane',
#        'Stationary Equipment - Generators & Boilers -Diesel',
#        'Stationary Equipment - Heating',
#        'Mobile Equipment - Non-highway - Diesel', 'Vehicles - CNG - CSH',
#        'Mobile Equipment - Non-highway - LPG/Propane',
#        'Vehicles - E85 - CSH',
#        'Stationary Equipment - Generator - Diesel', 'DSH-CNG-ASH',
#        'Mobile Equipment - Non-highway - Propane',
#        'Stationary Equipment - Generators - Diesel',
#        'Mobile Equipment - Nonhighway - Propane', 'Vehicles - Gasoline',
#        'Vehicles-Gas-ASH', 'Mobile Equipment -Nonhighway Diesel-Napa',
#        'Street Lighting', 'Vehicles-Gas-Sac', 'Vehicle Gasoline',
#        'Purchased Diesel Fuel', 'Biodiesel', 'Voyager E85',
#        'CNG fuel Usage', 'Diesel (from B5)', 'Unleaded Bulk Fuel',
#        'Voyager Gasoline', 'Bulk E85', 'Unleaded (from bulk E85)',
#        'Voyager Diesel', 'Voyager- LPG', 'Diesel Bulk Fuel',
#        'Purchased Electricity for Leased Facilities',
#        'Primary Electricity', 'Statewide Natural Gas Consumption',
#        'Bulk Biodiesel', 'Bulk Diesel (from B5)',
#        'Bulk unleaded (from E85)', 'Bulk Biodiesel (from B5)',
#        'Bulk Unleaded (from bulk E85)', 'Bulk E100 (from E85)',
#        'Voyager Ethanol (from E85)', 'Bulk Ethanol (from E85)',
#        'Biofuel -- Biogenic CO2', 'Biofuel -- CH4/N2O',
#        'Vehicle Fleet -- Diesel', 'Vehicle Fleet -- Gasoline',
#        'Biofuel -- Anthropogenic CO2', 'Generator Diesel Fuel', 'SF6',
#        'Mobile Gasoline Combustion - Bulk', 'Mobile Combustion - CNG',
#        'Mobile Gasoline Combustion', 'Mobile Diesel Combustion',
#        'Construction', 'Carbon Dioxide', 'Natural Gas Services (Heating)',
#        'Stationary Diesel Combustion', 'Acetylene/Welding',
#        'RG4 Fugitive Emissions', 'RG4 D9 Diesel', 'Net RG4',
#        'RG4 Coal Burned', 'RG4 Emergency Generator', 'RG4 Fire Pump',
#        'SWP Net Purchases', 'Net AMP', 'Net LEC', 'LEC',
#        'Passenger Cars (Model Year 1998 - Present)',
#        "Trucks/ Vans/ SUV's (Light) - (Model Year 1996)",
#        'Passenger Cars (Model Year 1992-1993)',
#        'Passenger Cars (Model Year 1995)',
#        'Passenger Cars (Model Year 1997)',
#        "Trucks/ Vans/ SUV's (Diesel) - (Model Year 1994)",
#        "Trucks/ Vans/ SUV's (Light) - (Model Year 1997)",
#        'Passenger Cars (Model Year 1994)',
#        'Passenger Cars (Model Year 1996)', 'Trucks, Heavy Duty (Diesel)',
#        "Trucks/ Vans/ SUV's (Light) - (Model Year 1989 - 1993)",
#        "Trucks/ Vans/ SUV's (Light) - (Model Year 1995)",
#        "Trucks/ Vans/ SUV's (Light) - (Model Year 1999 - Present)",
#        'GENERATOR', 'Generator Diesel', 'Vehicles',
#        'Purchased Electricity.', 'Unleaded Gasoline', 'GSA Diesel',
#        'gasoline', 'Road Diesel', 'Off-Road Diesel',
#        'CalEMA Fleet Diesel', 'CalEMA Fleet', 'Forklift Propane',
#        'CalEMA Electricity', 'CalEMA Natural Gas', 'E85 Fuel',
#        'E 85 gasoline', 'GSA Mogas', 'Propane - Forklift',
#        'Pressure Washer (Diesel)', 'Diesel - Backup Generators',
#        'Acetylene - Welding', 'R-404a Refrigerant',
#        'R-134a Air Conditioning', 'Vehicles - Diesel',
#        'Vehicles - Gasoline - Model Year 2002',
#        'Vehicles - Gasoline - Model Year 2006',
#        'Vehicles - Gasoline - Model Year 2007',
#        'Vehicles - Gasoline - Model Year 2008',
#        'Vehicles - Gasoline - Model Year 1998',
#        'Vehicles - Gasoline - Model Year 2009',
#        'Vehicles - Gasoline - Model Year 1999',
#        'Vehicles - Gasoline - Model Year 2001',
#        'Vehicles - Gasoline - Model Year 2005', 'R-134a Chillers',
#        'R-407c CRAC', 'Vehicles - Gasoline - Model Year 2004',
#        'Vehicles - Gasoline - Model Year 2012', 'FM-200 Fire Suppression',
#        'Renewable Energy Certificates',
#        'Vehicles - Gasoline - Model Year 2006 Passenger',
#        'Vehicles - Gasoline - Model Year 2015', 'Purchased Gas',
#        'Vehicles - Gasoline - Model Year 2009 Passenger',
#        'Plant Ops Equipment (Gasoline)',
#        'Forklift & Custodial Equipment (Propane)',
#        'State Vehicles - 2010 & 2011', 'Black Jeep - E400041',
#        'Ford Taurus - E409936', 'GMC Pick-Up Truck - E400047',
#        'Purple Jeep', 'Toyota Prius', 'Electricty Emissions',
#        'Refrigerant Fugutive Emissions', 'Purchased Natrual Gas',
#        'Fugitive Emissions, 29 domestic refrigerators', 'R410A', 'R407C',
#        'Mobile Combustiom - 2006 Honda Accord Hybrid',
#        'Mobile Combustion - 2004 Silverado',
#        'Mobile Combustion - 2006 Ford E-150',
#        'Mobile Combustion-2002 Impala', 'Electrical Meters 1&2',
#        'Natural Gas Meter',
#        'Stationary Combustion - Generator & Fire Pump',
#        'Fugutive Emissions, Vehicle AC', 'R404a', 'Fuel',
#        'Natural Gas Purchases-Furnaces (Generic)',
#        'Electricity Purchases', 'SNC Fleet Usage',
#        'Propane Usage-Furnaces (Generic)'], dtype=object)
