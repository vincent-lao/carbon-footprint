# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>JonesKammen Dataset</h1>

# %%
jonesKammen = pd.read_excel('../../data/Jones-Kammen-2014-Zip-City-County-Results.xlsx', sheet_name='zip code results')
jonesKammen_ca_zipcode = jonesKammen[jonesKammen['State'] == 'CA']
jonesKammen_ca_zipcode.head()
# Out:
#        ZipCode  Population  PersonsPerHousehold  AverageHouseValue  \
# 28629    90001       54481                 4.35             138900
# 28630    90002       44584                 4.16             127700
# 28631    90003       58187                 4.00             134400
# 28632    90004       67850                 2.91             371100
# 28633    90005       43014                 2.80             392200
#
#        IncomePerHousehold   Latitude   Longitude  Elevation State  \
# 28629               24207  33.974243 -118.245169        267    CA
# 28630               22872  33.949380 -118.245060        267    CA
# 28631               22346  33.963792 -118.274249        267    CA
# 28632               27591  34.076680 -118.308976        267    CA
# 28633               21998  34.058999 -118.312752        267    CA
#
#       StateFullName  ... FUELOIL (gallons) Vehicle miles traveled  \
# 28629    California  ...          0.000000                  15862
# ...

# %% [markdown]
# <h1> CoolClimate API Datasets </h1>

# %% [markdown]
# <h3>CoolClimate household 1 Dataset</h3>

# %%
coolClimate_household_1 = pd.read_csv('../../data/coolclimate-api-CAzips-singlehouseholds-withzc.csv')
X = coolClimate_household_1[['input_income', 'input_footprint_transportation_num_vehicles', 'input_footprint_transportation_mpg1', 'input_footprint_transportation_miles1', 'input_footprint_transportation_fuel1', 'input_footprint_transportation_airshort', 'input_footprint_transportation_airmedium','input_footprint_transportation_airlong', 'input_footprint_housing_cdd', 'input_footprint_housing_hdd', 'input_footprint_housing_electricity_dollars', 'input_footprint_housing_squarefeet', 'input_footprint_housing_watersewage', 'input_footprint_shopping_food_meatfisheggs_default', 'input_footprint_shopping_goods_clothing', 'input_footprint_shopping_goods_other_personalcare', 'input_footprint_shopping_services_education', 'input_footprint_shopping_services_total', 'Zip Code']]
y = coolClimate_household_1['result_grand_total']
labels = X[X.isna().any(axis=1)].index.values
newX = X.dropna(axis = 0, how = 'any')
newy = y.drop(labels, axis = 0)
data = newX
data['result_grand_total'] = newy


coolClimate_household_1 = data
coolClimate_household_1.head()
# Out:
# /Users/junkang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    input_income  input_footprint_transportation_num_vehicles  \
# 0           1.0                                          1.0
# 1           1.0                                          1.0
# 2           1.0                                          1.0
# 3           1.0                                          1.0
# 4           1.0                                          1.0
#
#    input_footprint_transportation_mpg1  input_footprint_transportation_miles1  \
# 0                                 22.0                                 8700.0
# ...

# %% [markdown]
# <h3>CoolClimate household 2 Dataset</h3>

# %%
coolClimate_household_2 = pd.read_csv("../../data/coolclimate-api-CAzips-size2households-withzc.csv")
X = coolClimate_household_2[['input_income', 'input_footprint_transportation_num_vehicles', 'input_footprint_transportation_mpg1', 'input_footprint_transportation_miles1', 'input_footprint_transportation_fuel1', 'input_footprint_transportation_airshort', 'input_footprint_transportation_airmedium','input_footprint_transportation_airlong', 'input_footprint_housing_cdd', 'input_footprint_housing_hdd', 'input_footprint_housing_electricity_dollars', 'input_footprint_housing_squarefeet', 'input_footprint_housing_watersewage', 'input_footprint_shopping_food_meatfisheggs_default', 'input_footprint_shopping_goods_clothing', 'input_footprint_shopping_goods_other_personalcare', 'input_footprint_shopping_services_education', 'input_footprint_shopping_services_total', 'Zip Code']]
y = coolClimate_household_2['result_grand_total']
labels = X[X.isna().any(axis=1)].index.values
newX = X.dropna(axis = 0, how = 'any')
newy = y.drop(labels, axis = 0)
data = newX
data['result_grand_total'] = newy


coolClimate_household_2 = data
coolClimate_household_2.head()
# Out:
# /Users/junkang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    input_income  input_footprint_transportation_num_vehicles  \
# 0           2.0                                          1.0
# 1           2.0                                          1.0
# 2           2.0                                          1.0
# 4           2.0                                          1.0
# 5           2.0                                          1.0
#
#    input_footprint_transportation_mpg1  input_footprint_transportation_miles1  \
# 0                                 22.0                                 5200.0
# ...

# %% [markdown]
# <h3>CoolClimate household 3 Dataset</h3>

# %%
coolClimate_household_3 = pd.read_csv("../../data/coolclimate-api-CAzips-size3households-withzc.csv")
X = coolClimate_household_3[['input_income', 'input_footprint_transportation_num_vehicles', 'input_footprint_transportation_mpg1', 'input_footprint_transportation_miles1', 'input_footprint_transportation_fuel1', 'input_footprint_transportation_airshort', 'input_footprint_transportation_airmedium','input_footprint_transportation_airlong', 'input_footprint_housing_cdd', 'input_footprint_housing_hdd', 'input_footprint_housing_electricity_dollars', 'input_footprint_housing_squarefeet', 'input_footprint_housing_watersewage', 'input_footprint_shopping_food_meatfisheggs_default', 'input_footprint_shopping_goods_clothing', 'input_footprint_shopping_goods_other_personalcare', 'input_footprint_shopping_services_education', 'input_footprint_shopping_services_total', 'Zip Code']]
y = coolClimate_household_3['result_grand_total']
labels = X[X.isna().any(axis=1)].index.values
newX = X.dropna(axis = 0, how = 'any')
newy = y.drop(labels, axis = 0)
data = newX
data['result_grand_total'] = newy

coolClimate_household_3 = data
coolClimate_household_3.head()
# Out:
# /Users/junkang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    input_income  input_footprint_transportation_num_vehicles  \
# 0           2.0                                          1.0
# 1           2.0                                          1.0
# 2           2.0                                          1.0
# 3           2.0                                          1.0
# 4           2.0                                          1.0
#
#    input_footprint_transportation_mpg1  input_footprint_transportation_miles1  \
# 0                                 22.0                                 8400.0
# ...

# %% [markdown]
# <h3>CoolClimate household 4 Dataset</h3>

# %%
coolClimate_household_4 = pd.read_csv("../../data/coolclimate-api-CAzips-size4households-withzc.csv")
X = coolClimate_household_4[['input_income', 'input_footprint_transportation_num_vehicles', 
                             'input_footprint_transportation_mpg1', 'input_footprint_transportation_miles1', 
                             'input_footprint_transportation_fuel1', 'input_footprint_transportation_airshort', 
                             'input_footprint_transportation_airmedium','input_footprint_transportation_airlong', 
                             'input_footprint_housing_cdd', 'input_footprint_housing_hdd', 'input_footprint_housing_electricity_dollars', 
                             'input_footprint_housing_squarefeet', 'input_footprint_housing_watersewage', 
                             'input_footprint_shopping_food_meatfisheggs_default', 'input_footprint_shopping_goods_clothing', 
                             'input_footprint_shopping_goods_other_personalcare', 'input_footprint_shopping_services_education', 
                             'input_footprint_shopping_services_total', 'Zip Code']]
y = coolClimate_household_4['result_grand_total']
labels = X[X.isna().any(axis=1)].index.values
newX = X.dropna(axis = 0, how = 'any')
newy = y.drop(labels, axis = 0)
data = newX
data['result_grand_total'] = newy

coolClimate_household_4 = data
coolClimate_household_4.head()
# Out:
# /Users/junkang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#    input_income  input_footprint_transportation_num_vehicles  \
# 0           1.0                                          3.0
# 1           1.0                                          3.0
# 2           1.0                                          3.0
# 3           1.0                                          3.0
# 4           1.0                                          3.0
#
#    input_footprint_transportation_mpg1  input_footprint_transportation_miles1  \
# 0                                 22.0                                 9500.0
# ...

# %% [markdown]
# <h3>CoolClimate household 5 Dataset</h3>

# %%
coolClimate_household_5 = pd.read_csv("../../data/coolclimate-api-CAzips-size5households-withzc.csv")
X = coolClimate_household_5[['input_income', 'input_footprint_transportation_num_vehicles', 
                             'input_footprint_transportation_mpg1', 'input_footprint_transportation_miles1', 
                             'input_footprint_transportation_fuel1', 'input_footprint_transportation_airshort', 
                             'input_footprint_transportation_airmedium','input_footprint_transportation_airlong', 
                             'input_footprint_housing_cdd', 'input_footprint_housing_hdd', 'input_footprint_housing_electricity_dollars', 
                             'input_footprint_housing_squarefeet', 'input_footprint_housing_watersewage', 
                             'input_footprint_shopping_food_meatfisheggs_default', 'input_footprint_shopping_goods_clothing', 
                             'input_footprint_shopping_goods_other_personalcare', 'input_footprint_shopping_services_education', 
                             'input_footprint_shopping_services_total', 'Zip Code']]
y = coolClimate_household_5['result_grand_total']
labels = X[X.isna().any(axis=1)].index.values
newX = X.dropna(axis = 0, how = 'any')
newy = y.drop(labels, axis = 0)
data = newX
data['result_grand_total'] = newy

coolClimate_household_5 = data
coolClimate_household_5.head()
# Out:
# /Users/junkang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#    input_income  input_footprint_transportation_num_vehicles  \
# 0           1.0                                          3.0
# 1           1.0                                          3.0
# 2           1.0                                          3.0
# 3           1.0                                          3.0
# 4           1.0                                          3.0
#
#    input_footprint_transportation_mpg1  input_footprint_transportation_miles1  \
# 0                                 22.0                                 9900.0
# ...

# %% [markdown]
# <h3>Concatenated CoolClimate Datasets</h3>

# %%
coolClimate = pd.concat([coolClimate_household_1, coolClimate_household_2, coolClimate_household_3, coolClimate_household_4,
                        coolClimate_household_5])
coolClimate.head()
coolClimate.shape
# Out:
# (5710, 20)

# %%
coolClimate['Zip Code'] = coolClimate['Zip Code'].astype('int')

coolClimate['Zip Code']

coolClimate = coolClimate.rename(columns={'Zip Code': 'ZipCode'})

coolClimate.head()
# Out:
#    input_income  input_footprint_transportation_num_vehicles  \
# 0           1.0                                          1.0
# 1           1.0                                          1.0
# 2           1.0                                          1.0
# 3           1.0                                          1.0
# 4           1.0                                          1.0
#
#    input_footprint_transportation_mpg1  input_footprint_transportation_miles1  \
# 0                                 22.0                                 8700.0
# 1                                 22.0                                 8500.0
# 2                                 22.0                                 8000.0
# 3                                 22.0                                 7300.0
# 4                                 22.0                                 6000.0
#
#    input_footprint_transportation_fuel1  \
# 0                                   1.0
# 1                                   1.0
# ...

# %%
coolClimate_grouped_by = coolClimate.groupby(['ZipCode']).sum()
coolClimate_grouped_by.head()
# Out:
#          input_income  input_footprint_transportation_num_vehicles  \
# ZipCode
# 90001            39.0                                         21.0
# 90002            45.0                                         23.0
# 90003            39.0                                         21.0
# 90004            29.0                                         17.0
# 90005            27.0                                         16.0
#
#          input_footprint_transportation_mpg1  \
# ZipCode
# 90001                                  220.0
# 90002                                  242.0
# 90003                                  220.0
# 90004                                  176.0
# 90005                                  198.0
#
#          input_footprint_transportation_miles1  \
# ZipCode
# 90001                                  88700.0
# 90002                                  95400.0
# 90003                                  81800.0
# 90004                                  57900.0
# ...

# %%
jonesKammen_ca_zipcode = jonesKammen_ca_zipcode.drop(columns=["Latitude", "Longitude", "Elevation", "State", "StateFullName", 
                                    "City", "CBSAType", "CBSAName","MSAName", "PMSA_Name", "Region", 
                                    "Division", "Transport (tCO2e/yr)", "Housing (tCO2e/yr)", "Food (tCO2e/yr)",
                                    "Goods (tCO2e/yr)", "Services (tCO2e/yr)", 
                                     "Total Household Carbon Footprint (tCO2e/yr)", "Total Zip Code Carbon Footprint (tCO2e/yr)"])
jonesKammen_ca_zipcode.head()
# Out:
#        ZipCode  Population  PersonsPerHousehold  AverageHouseValue  \
# 28629    90001       54481                 4.35             138900
# 28630    90002       44584                 4.16             127700
# 28631    90003       58187                 4.00             134400
# 28632    90004       67850                 2.91             371100
# 28633    90005       43014                 2.80             392200
#
#        IncomePerHousehold   CountyName        popden  electricity (kWh)  \
# 28629               24207  LOS ANGELES  15688.048535        6136.401626
# 28630               22872  LOS ANGELES  14677.391372        6566.231955
# 28631               22346  LOS ANGELES  16440.618870        6298.857437
# 28632               27591  LOS ANGELES  22196.421812        4645.592721
# 28633               21998  LOS ANGELES  37517.695175        4076.030763
#
#        Nat. Gas (cu.ft.)  FUELOIL (gallons)  Vehicle miles traveled  \
# ...

# %%
mergedZC = coolClimate_grouped_by.join(jonesKammen_ca_zipcode.set_index('ZipCode'))
mergedZC
# Out:
#          input_income  input_footprint_transportation_num_vehicles  \
# ZipCode
# 90001            39.0                                         21.0
# 90002            45.0                                         23.0
# 90003            39.0                                         21.0
# 90004            29.0                                         17.0
# 90005            27.0                                         16.0
# ...               ...                                          ...
# 96145            38.0                                         16.0
# 96146            27.0                                         13.0
# 96148            37.0                                         16.0
# 96150            36.0                                         16.0
# 96161            29.0                                         14.0
#
#          input_footprint_transportation_mpg1  \
# ZipCode
# 90001                                  220.0
# 90002                                  242.0
# ...

# %%
final_dataset = mergedZC.groupby(['CountyName']).sum()
final_dataset = final_dataset.drop(columns=["input_income"])
final_dataset.head()
# Out:
#             input_footprint_transportation_num_vehicles  \
# CountyName
# ALAMEDA                                           242.0
# ALPINE                                             15.0
# AMADOR                                             87.0
# BUTTE                                             123.0
# CALAVERAS                                         175.0
#
#             input_footprint_transportation_mpg1  \
# CountyName
# ALAMEDA                                  2728.0
# ALPINE                                    176.0
# AMADOR                                    836.0
# BUTTE                                    1408.0
# CALAVERAS                                1584.0
#
#             input_footprint_transportation_miles1  \
# CountyName
# ALAMEDA                                 1613500.0
# ALPINE                                    86300.0
# AMADOR                                   700100.0
# BUTTE                                    998900.0
# ...

# %%
final_dataset.to_csv('../../data/jonesKammen-PlUS-CoolClimate.csv')
